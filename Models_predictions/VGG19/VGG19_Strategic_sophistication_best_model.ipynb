# %% [markdown]
# # Model Testing and Predictions on Smaller images
#
# # VGG19 trained on AOI
#
# # Multiclass prediction task

# %% [markdown]
# # 1. Set up

# %%
 from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14777060244402414525
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8655809544832683700
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !pip install tensorflow-addons --quiet
# Out:
#      |████████████████████████████████| 1.1 MB 15.8 MB/s

# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.models import Model, save_model, load_model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.applications.vgg19 import preprocess_input
from keras import backend as K
import tensorflow_addons as tfa
import os
import tempfile


from keras.utils.vis_utils import plot_model

# %%
# Define paths:
pathtoCSV = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/CSV_Files/'
pathtoImages = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/'
pathtoSave = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Saved_models/VGG19/'
pathtoResults = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Models_performance/VGG19/Strategic_sophistication/'

# %% [markdown]
# #2. Input Pipeline

# %%
labels_csv = pd.read_csv(pathtoCSV + 'train_val_levels.csv',dtype=str)

# %%
def image_generator(pathtoImages ):
  train_datagen = ImageDataGenerator(
      preprocessing_function = preprocess_input,
  )
  val_datagen = ImageDataGenerator(
      preprocessing_function = preprocess_input,
  )
  labels_csv['Levels'] = labels_csv['Levels'].astype(str)
  labels_csv['code'] = labels_csv['code'].astype(str)


  train_generator = train_datagen.flow_from_dataframe(
      labels_csv,
      directory = pathtoImages + 'Train',
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=True,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
  )

  val_generator = val_datagen.flow_from_dataframe(
      labels_csv,
      directory = pathtoImages + 'Validation',
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=True,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
  )
  return train_generator, val_generator

train_generator, val_generator = image_generator(pathtoImages)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 480 invalid image filename(s) in x_col="code". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# Found 1700 validated image filenames belonging to 3 classes.
# Found 480 validated image filenames belonging to 3 classes.
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 1700 invalid image filename(s) in x_col="code". These filename(s) will be ignored.
#   .format(n_invalid, x_col)

# %%
# plotting train images
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(15,15))

for i in range(4):
  # convert to unsigned integers for plotting
  image = next(train_generator)[0][i].astype('float')
  # plot raw pixel data
  ax[i].imshow(image)
  ax[i].axis('off')

# plotting val images
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(15,15))

for i in range(4):

  # convert to unsigned integers for plotting
  image = next(val_generator)[0][i].astype('float')
  # plot raw pixel data
  ax[i].imshow(image)
  ax[i].axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #3. Best model found by Bayesian Tuner

# %% [markdown]
# Trial summary of best model found by Bayesian tuner:\
# units_1: 1024\
# dropout_1: 0.5000000000000001

# %%
# Define early-stopping:
early_stopping_1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    verbose=1,
    patience=4, 
    mode='auto',
    restore_best_weights=True)

# %%
def recall(y_true, y_pred):
    y_true = K.ones_like(y_true) 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    all_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    
    recall = true_positives / (all_positives + K.epsilon())
    return recall

# %%
METRICS = [  
      keras.metrics.CategoricalAccuracy(name='accuracy'),
      recall,
      keras.metrics.AUC(name='auc', multi_label = True),
      keras.metrics.AUC(curve = 'PR', name='PR', multi_label = True),
      tfa.metrics.F1Score(name = 'f1macro', num_classes = 3, average = 'macro'),
      tfa.metrics.F1Score(name = 'f1weighted', num_classes = 3, average = 'weighted'),
]

# %%
# Original code source for regularizer: https://sthalles.github.io/keras-regularizer/

def build_model():
  base_model = VGG19(weights='imagenet', include_top=False)
  for layers in base_model.layers:
    layers.trainable=False
  x= base_model.output
  x= GlobalAveragePooling2D()(x)
  x= Dense(1024,activation='relu')(x)
  x=Dropout(0.5000000000000001)(x)
  output=Dense(3,activation='softmax')(x)
  model=Model(inputs=base_model.input,outputs=output)
  regularizer=tf.keras.regularizers.L1L2(1e-5)
  if not isinstance(regularizer, tf.keras.regularizers.Regularizer):
    print("Regularizer must be a subclass of tf.keras.regularizers.Regularizer")
    return model

  for layer in model.layers:
    for attr in ['kernel_regularizer']:
      if hasattr(layer, attr):
        setattr(layer, attr, regularizer)

  # When we change the layers attributes, the change only happens in the model config file
  model_json = model.to_json()

  # Save the weights before reloading the model.
  tmp_weights_path = os.path.join(tempfile.gettempdir(), 'tmp_weights.h5')
  model.save_weights(tmp_weights_path)

  # load the model from the config
  model = tf.keras.models.model_from_json(model_json)
    
  # Reload the model weights
  model.load_weights(tmp_weights_path, by_name=True)
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(1e-5, decay_steps=100000, decay_rate=0.75, staircase=True)
  opt = SGD(learning_rate = lr_schedule, momentum=0.99) 
  model.compile(optimizer=opt, loss=tfa.losses.SigmoidFocalCrossEntropy(gamma = 2, alpha= 0.25, reduction=tf.keras.losses.Reduction.AUTO), metrics= METRICS)
  return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step

# %%
 model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 3)                 3075
#
# =================================================================
# Total params: 20,552,771
# Trainable params: 528,387
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
history = model.fit(
    train_generator,
    batch_size = 16,
    epochs = 40,
    callbacks= early_stopping_1,
    validation_data = val_generator,
    shuffle = True
)
# Out:
# Epoch 1/40
# 107/107 [==============================] - 958s 9s/step - loss: 3.3918 - accuracy: 0.3535 - recall: 0.3203 - auc: 0.4982 - PR: 0.3272 - f1macro: 0.3242 - f1weighted: 0.3598 - val_loss: 1.8600 - val_accuracy: 0.4250 - val_recall: 0.2611 - val_auc: 0.6442 - val_PR: 0.4660 - val_f1macro: 0.3547 - val_f1weighted: 0.3931
# Epoch 2/40
# 107/107 [==============================] - 83s 778ms/step - loss: 2.6187 - accuracy: 0.4406 - recall: 0.3185 - auc: 0.5892 - PR: 0.4125 - f1macro: 0.3937 - f1weighted: 0.4428 - val_loss: 1.8769 - val_accuracy: 0.5479 - val_recall: 0.2972 - val_auc: 0.7124 - val_PR: 0.5491 - val_f1macro: 0.5091 - val_f1weighted: 0.5532
# Epoch 3/40
# 107/107 [==============================] - 84s 782ms/step - loss: 2.2181 - accuracy: 0.5200 - recall: 0.3102 - auc: 0.6571 - PR: 0.4692 - f1macro: 0.4743 - f1weighted: 0.5250 - val_loss: 1.8285 - val_accuracy: 0.6167 - val_recall: 0.3014 - val_auc: 0.7436 - val_PR: 0.5658 - val_f1macro: 0.4606 - val_f1weighted: 0.5466
# Epoch 4/40
# 107/107 [==============================] - 83s 778ms/step - loss: 1.9779 - accuracy: 0.5065 - recall: 0.3018 - auc: 0.6438 - PR: 0.4697 - f1macro: 0.4532 - f1weighted: 0.5035 - val_loss: 1.8134 - val_accuracy: 0.5167 - val_recall: 0.3042 - val_auc: 0.7244 - val_PR: 0.5482 - val_f1macro: 0.3860 - val_f1weighted: 0.4582
# Epoch 5/40
# 107/107 [==============================] - 83s 772ms/step - loss: 1.8225 - accuracy: 0.5124 - recall: 0.2767 - auc: 0.6550 - PR: 0.4749 - f1macro: 0.4584 - f1weighted: 0.5103 - val_loss: 1.6593 - val_accuracy: 0.6000 - val_recall: 0.2681 - val_auc: 0.7457 - val_PR: 0.5827 - val_f1macro: 0.4485 - val_f1weighted: 0.5324
# Epoch 6/40
# 107/107 [==============================] - 82s 767ms/step - loss: 1.7217 - accuracy: 0.5088 - recall: 0.2416 - auc: 0.6440 - PR: 0.4637 - f1macro: 0.4501 - f1weighted: 0.5017 - val_loss: 1.6514 - val_accuracy: 0.5958 - val_recall: 0.2514 - val_auc: 0.7187 - val_PR: 0.5392 - val_f1macro: 0.4434 - val_f1weighted: 0.5270
# Epoch 7/40
# 107/107 [==============================] - 84s 785ms/step - loss: 1.6825 - accuracy: 0.5206 - recall: 0.2216 - auc: 0.6532 - PR: 0.4696 - f1macro: 0.4713 - f1weighted: 0.5184 - val_loss: 1.6049 - val_accuracy: 0.5354 - val_recall: 0.1590 - val_auc: 0.7403 - val_PR: 0.5791 - val_f1macro: 0.4321 - val_f1weighted: 0.4953
# Epoch 8/40
# 107/107 [==============================] - 84s 783ms/step - loss: 1.6443 - accuracy: 0.5306 - recall: 0.1943 - auc: 0.6754 - PR: 0.4915 - f1macro: 0.4805 - f1weighted: 0.5286 - val_loss: 1.5953 - val_accuracy: 0.5521 - val_recall: 0.1410 - val_auc: 0.7358 - val_PR: 0.5704 - val_f1macro: 0.4349 - val_f1weighted: 0.5047
# Epoch 9/40
# 107/107 [==============================] - 83s 774ms/step - loss: 1.6124 - accuracy: 0.5512 - recall: 0.1663 - auc: 0.7009 - PR: 0.5260 - f1macro: 0.5026 - f1weighted: 0.5474 - val_loss: 1.5817 - val_accuracy: 0.6146 - val_recall: 0.1528 - val_auc: 0.7406 - val_PR: 0.5752 - val_f1macro: 0.4850 - val_f1weighted: 0.5617
# Epoch 10/40
# 107/107 [==============================] - 83s 782ms/step - loss: 1.6069 - accuracy: 0.5682 - recall: 0.1711 - auc: 0.7043 - PR: 0.5238 - f1macro: 0.5097 - f1weighted: 0.5597 - val_loss: 1.5814 - val_accuracy: 0.6104 - val_recall: 0.1028 - val_auc: 0.7341 - val_PR: 0.5693 - val_f1macro: 0.5657 - val_f1weighted: 0.6102
# Epoch 11/40
# 107/107 [==============================] - 83s 778ms/step - loss: 1.5938 - accuracy: 0.5982 - recall: 0.1587 - auc: 0.7139 - PR: 0.5418 - f1macro: 0.5290 - f1weighted: 0.5848 - val_loss: 1.5791 - val_accuracy: 0.6229 - val_recall: 0.1306 - val_auc: 0.7430 - val_PR: 0.5823 - val_f1macro: 0.5508 - val_f1weighted: 0.6038
# Epoch 12/40
# 107/107 [==============================] - 83s 774ms/step - loss: 1.5873 - accuracy: 0.5912 - recall: 0.1425 - auc: 0.7240 - PR: 0.5623 - f1macro: 0.5404 - f1weighted: 0.5862 - val_loss: 1.5801 - val_accuracy: 0.6354 - val_recall: 0.1604 - val_auc: 0.7470 - val_PR: 0.5850 - val_f1macro: 0.4897 - val_f1weighted: 0.5717
# Epoch 13/40
# 107/107 [==============================] - 82s 770ms/step - loss: 1.5819 - accuracy: 0.5994 - recall: 0.1400 - auc: 0.7394 - PR: 0.5722 - f1macro: 0.5439 - f1weighted: 0.5929 - val_loss: 1.5786 - val_accuracy: 0.6146 - val_recall: 0.1188 - val_auc: 0.7366 - val_PR: 0.5692 - val_f1macro: 0.5112 - val_f1weighted: 0.5765
# Epoch 14/40
# 107/107 [==============================] - 83s 774ms/step - loss: 1.5776 - accuracy: 0.6012 - recall: 0.1386 - auc: 0.7423 - PR: 0.5813 - f1macro: 0.5319 - f1weighted: 0.5857 - val_loss: 1.5736 - val_accuracy: 0.6167 - val_recall: 0.0889 - val_auc: 0.7402 - val_PR: 0.5803 - val_f1macro: 0.5578 - val_f1weighted: 0.6068
# Epoch 15/40
# 107/107 [==============================] - 83s 778ms/step - loss: 1.5754 - accuracy: 0.6165 - recall: 0.1355 - auc: 0.7481 - PR: 0.5868 - f1macro: 0.5568 - f1weighted: 0.6059 - val_loss: 1.5774 - val_accuracy: 0.6396 - val_recall: 0.1542 - val_auc: 0.7487 - val_PR: 0.5922 - val_f1macro: 0.5221 - val_f1weighted: 0.5915
# Epoch 16/40
# 107/107 [==============================] - 82s 768ms/step - loss: 1.5725 - accuracy: 0.6206 - recall: 0.1417 - auc: 0.7612 - PR: 0.6018 - f1macro: 0.5603 - f1weighted: 0.6094 - val_loss: 1.5729 - val_accuracy: 0.6292 - val_recall: 0.1208 - val_auc: 0.7451 - val_PR: 0.5866 - val_f1macro: 0.5294 - val_f1weighted: 0.5922
# Epoch 17/40
# 107/107 [==============================] - 83s 773ms/step - loss: 1.5718 - accuracy: 0.6218 - recall: 0.1324 - auc: 0.7557 - PR: 0.5965 - f1macro: 0.5623 - f1weighted: 0.6092 - val_loss: 1.5717 - val_accuracy: 0.6396 - val_recall: 0.1056 - val_auc: 0.7443 - val_PR: 0.5846 - val_f1macro: 0.5671 - val_f1weighted: 0.6198
# Epoch 18/40
# 107/107 [==============================] - 83s 776ms/step - loss: 1.5705 - accuracy: 0.6418 - recall: 0.1318 - auc: 0.7698 - PR: 0.5965 - f1macro: 0.5802 - f1weighted: 0.6302 - val_loss: 1.5751 - val_accuracy: 0.6042 - val_recall: 0.1194 - val_auc: 0.7460 - val_PR: 0.5843 - val_f1macro: 0.4928 - val_f1weighted: 0.5611
# Epoch 19/40
# 107/107 [==============================] - 82s 771ms/step - loss: 1.5689 - accuracy: 0.6300 - recall: 0.1342 - auc: 0.7640 - PR: 0.6052 - f1macro: 0.5662 - f1weighted: 0.6170 - val_loss: 1.5754 - val_accuracy: 0.6396 - val_recall: 0.1347 - val_auc: 0.7495 - val_PR: 0.5929 - val_f1macro: 0.5339 - val_f1weighted: 0.5977
# Epoch 20/40
# 107/107 [==============================] - 82s 768ms/step - loss: 1.5708 - accuracy: 0.6147 - recall: 0.1252 - auc: 0.7605 - PR: 0.5968 - f1macro: 0.5614 - f1weighted: 0.6064 - val_loss: 1.5730 - val_accuracy: 0.6438 - val_recall: 0.1229 - val_auc: 0.7453 - val_PR: 0.5870 - val_f1macro: 0.5426 - val_f1weighted: 0.6061
# Epoch 21/40
# 107/107 [==============================] - ETA: 0s - loss: 1.5637 - accuracy: 0.6453 - recall: 0.1305 - auc: 0.7825 - PR: 0.6339 - f1macro: 0.5876 - f1weighted: 0.6321Restoring model weights from the end of the best epoch: 17.
# 107/107 [==============================] - 82s 769ms/step - loss: 1.5637 - accuracy: 0.6453 - recall: 0.1305 - auc: 0.7825 - PR: 0.6339 - f1macro: 0.5876 - f1weighted: 0.6321 - val_loss: 1.5735 - val_accuracy: 0.6354 - val_recall: 0.1146 - val_auc: 0.7456 - val_PR: 0.5855 - val_f1macro: 0.5514 - val_f1weighted: 0.6071
# Epoch 00021: early stopping

# %%
def plot_metrics(history, name_file):
  '''
  Funcitons to plot metrics ('accuracy', 'tp', 'fp', 'loss', 'tn', 'fn',  'precision', 'recall', 'auc') in subplots.
  Adjust the figsize for overlal size of plot
  Adjust fontsize for labels
  Adjust linewidth for line of graphs

  Args:
   History - tensorflow object
  
  Returns:
  '''
  metrics = ['loss', 'accuracy','recall', 'auc', 'PR', 'f1macro', 'f1weighted' ]
  fig, ax = plt.subplots(3,3, figsize=(30,20))
  fig.suptitle('Model Metric Plots',fontsize=40)
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(3,3,n+1)
    plt.plot(history.epoch, history.history[metric], label='Train', linewidth=3)
    plt.plot(history.epoch, history.history['val_'+metric], linestyle="--", label='Val', linewidth=3)
    plt.xlabel('Epoch', fontsize=10)
    plt.title(str(name))
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])

    plt.legend(fontsize=10)
    plt.savefig(pathtoResults + name_file)

# %%
plot_metrics(history= history, name_file ='history_val.png')

# %%
#convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history)
frames = [hist_df]
result = pd.concat(frames)
# or save to csv: 
hist_csv_file = pathtoResults + 'history_val.csv'
with open(hist_csv_file, mode='w') as f:
    result.to_csv(f)

# %% [markdown]
# #4. Fine tune model with best tuning identified by Randomsearch

# %% [markdown]
# Trial summary\
# Hyperparameters:\
# num_frozen_layers: 8\
# learning_rate: 1e-06

# %%
# Define early-stopping:
early_stopping_2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    verbose=1,
    patience=3, 
    mode='auto',
    restore_best_weights=True)

# %%
# reset the train and validation generators:
train_generator.reset()
val_generator.reset()

# %%
for layer in model.layers[3:]:
	layer.trainable = True

# %%
lr_sched = tf.keras.optimizers.schedules.ExponentialDecay(1e-6, decay_steps=100000, decay_rate=0.75, staircase=True)
opt_2 = SGD(learning_rate = lr_sched, momentum=0.99) 
model.compile(optimizer=opt_2, loss=tfa.losses.SigmoidFocalCrossEntropy(gamma = 2, alpha= 0.25, reduction=tf.keras.losses.Reduction.AUTO), metrics= METRICS)

# %%
history_2 = model.fit(
    train_generator,
    batch_size = 16,
    epochs = 20,
    callbacks= early_stopping_2,
    validation_data = val_generator,
    shuffle = True
)
# Out:
# Epoch 1/20
# 107/107 [==============================] - 92s 825ms/step - loss: 1.5684 - accuracy: 0.6321 - recall: 0.1279 - auc: 0.7628 - PR: 0.6074 - f1macro: 0.5700 - f1weighted: 0.6200 - val_loss: 1.5719 - val_accuracy: 0.6375 - val_recall: 0.1160 - val_auc: 0.7459 - val_PR: 0.5854 - val_f1macro: 0.5421 - val_f1weighted: 0.6038
# Epoch 2/20
# 107/107 [==============================] - 85s 795ms/step - loss: 1.5658 - accuracy: 0.6441 - recall: 0.1336 - auc: 0.7736 - PR: 0.6209 - f1macro: 0.5811 - f1weighted: 0.6299 - val_loss: 1.5728 - val_accuracy: 0.6396 - val_recall: 0.1042 - val_auc: 0.7417 - val_PR: 0.5780 - val_f1macro: 0.5559 - val_f1weighted: 0.6130
# Epoch 3/20
# 107/107 [==============================] - 85s 793ms/step - loss: 1.5680 - accuracy: 0.6241 - recall: 0.1182 - auc: 0.7631 - PR: 0.6102 - f1macro: 0.5590 - f1weighted: 0.6116 - val_loss: 1.5720 - val_accuracy: 0.6438 - val_recall: 0.1069 - val_auc: 0.7433 - val_PR: 0.5818 - val_f1macro: 0.5468 - val_f1weighted: 0.6088
# Epoch 4/20
# 107/107 [==============================] - 85s 796ms/step - loss: 1.5651 - accuracy: 0.6335 - recall: 0.1176 - auc: 0.7693 - PR: 0.6132 - f1macro: 0.5556 - f1weighted: 0.6131 - val_loss: 1.5719 - val_accuracy: 0.6333 - val_recall: 0.0979 - val_auc: 0.7413 - val_PR: 0.5817 - val_f1macro: 0.5380 - val_f1weighted: 0.5993
# Epoch 5/20
# 107/107 [==============================] - 86s 805ms/step - loss: 1.5609 - accuracy: 0.6453 - recall: 0.1184 - auc: 0.7845 - PR: 0.6360 - f1macro: 0.5876 - f1weighted: 0.6341 - val_loss: 1.5710 - val_accuracy: 0.6375 - val_recall: 0.1014 - val_auc: 0.7451 - val_PR: 0.5839 - val_f1macro: 0.5577 - val_f1weighted: 0.6125
# Epoch 6/20
# 107/107 [==============================] - 85s 797ms/step - loss: 1.5609 - accuracy: 0.6494 - recall: 0.1184 - auc: 0.7815 - PR: 0.6385 - f1macro: 0.5805 - f1weighted: 0.6333 - val_loss: 1.5692 - val_accuracy: 0.6479 - val_recall: 0.1188 - val_auc: 0.7523 - val_PR: 0.5919 - val_f1macro: 0.5527 - val_f1weighted: 0.6144
# Epoch 7/20
# 107/107 [==============================] - 86s 803ms/step - loss: 1.5598 - accuracy: 0.6441 - recall: 0.1236 - auc: 0.7866 - PR: 0.6374 - f1macro: 0.5636 - f1weighted: 0.6228 - val_loss: 1.5695 - val_accuracy: 0.6250 - val_recall: 0.1174 - val_auc: 0.7525 - val_PR: 0.5909 - val_f1macro: 0.5296 - val_f1weighted: 0.5924
# Epoch 8/20
# 107/107 [==============================] - 86s 808ms/step - loss: 1.5562 - accuracy: 0.6488 - recall: 0.1310 - auc: 0.7988 - PR: 0.6600 - f1macro: 0.5788 - f1weighted: 0.6317 - val_loss: 1.5695 - val_accuracy: 0.6313 - val_recall: 0.1201 - val_auc: 0.7564 - val_PR: 0.5925 - val_f1macro: 0.5433 - val_f1weighted: 0.6017
# Epoch 9/20
# 107/107 [==============================] - 86s 801ms/step - loss: 1.5579 - accuracy: 0.6624 - recall: 0.1254 - auc: 0.7985 - PR: 0.6518 - f1macro: 0.6032 - f1weighted: 0.6501 - val_loss: 1.5677 - val_accuracy: 0.6417 - val_recall: 0.1181 - val_auc: 0.7599 - val_PR: 0.5999 - val_f1macro: 0.5468 - val_f1weighted: 0.6083
# Epoch 10/20
# 107/107 [==============================] - 85s 794ms/step - loss: 1.5555 - accuracy: 0.6606 - recall: 0.1314 - auc: 0.8069 - PR: 0.6660 - f1macro: 0.5990 - f1weighted: 0.6453 - val_loss: 1.5671 - val_accuracy: 0.6417 - val_recall: 0.1160 - val_auc: 0.7595 - val_PR: 0.6003 - val_f1macro: 0.5444 - val_f1weighted: 0.6084
# Epoch 11/20
# 107/107 [==============================] - 85s 798ms/step - loss: 1.5561 - accuracy: 0.6600 - recall: 0.1254 - auc: 0.8028 - PR: 0.6603 - f1macro: 0.6063 - f1weighted: 0.6508 - val_loss: 1.5681 - val_accuracy: 0.6438 - val_recall: 0.1174 - val_auc: 0.7585 - val_PR: 0.5992 - val_f1macro: 0.5431 - val_f1weighted: 0.6077
# Epoch 12/20
# 107/107 [==============================] - 85s 797ms/step - loss: 1.5535 - accuracy: 0.6665 - recall: 0.1355 - auc: 0.8088 - PR: 0.6715 - f1macro: 0.6001 - f1weighted: 0.6484 - val_loss: 1.5676 - val_accuracy: 0.6417 - val_recall: 0.1250 - val_auc: 0.7608 - val_PR: 0.6009 - val_f1macro: 0.5423 - val_f1weighted: 0.6068
# Epoch 13/20
# 107/107 [==============================] - ETA: 0s - loss: 1.5531 - accuracy: 0.6747 - recall: 0.1262 - auc: 0.8079 - PR: 0.6718 - f1macro: 0.6187 - f1weighted: 0.6639Restoring model weights from the end of the best epoch: 10.
# 107/107 [==============================] - 85s 790ms/step - loss: 1.5531 - accuracy: 0.6747 - recall: 0.1262 - auc: 0.8079 - PR: 0.6718 - f1macro: 0.6187 - f1weighted: 0.6639 - val_loss: 1.5676 - val_accuracy: 0.6521 - val_recall: 0.1250 - val_auc: 0.7601 - val_PR: 0.6008 - val_f1macro: 0.5491 - val_f1weighted: 0.6147
# Epoch 00013: early stopping

# %%
# !mkdir -p saved_models_and_weights
model.save(filepath = pathtoSave + 'VGG_19_Strategic_sophistication_best_model')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Saved_models/VGG19/VGG_19_Strategic_sophistication_best_model/assets

# %%
plot_metrics(history=history_2, name_file = 'history_best_model_val.png')

# %%
#convert the history.history dict to a pandas DataFrame:     
hist_df_2 = pd.DataFrame(history_2.history)
frames = [hist_df_2]
result = pd.concat(frames)
# or save to csv: 
hist_csv_file = pathtoResults + 'history_best_model_val.csv'
with open(hist_csv_file, mode='w') as f:
    result.to_csv(f)

# %% [markdown]
# #5. Test Generators

# %%
# load test data:
labels_xl = pd.read_csv(pathtoCSV + 'test_L1L2.csv',dtype=str)

# Paths to test images:
test_percentage = 'test_percentages/'
test_timing = 'test_timings/'

# %%
def load_test_images(test_full, test_80, test_50, test_30, test_15, test_15s, test_10s, test_5s, test_2s):
  test_datagen = ImageDataGenerator(
      preprocessing_function = preprocess_input,
  )
  labels_xl['Levels'] = labels_xl['Levels'].astype(str)
  labels_xl['code'] = labels_xl['code'].astype(str)

  test_generator_full_images = test_datagen.flow_from_dataframe(
      labels_xl,
      directory = test_full,
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=False,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
)
  test_generator_80_percent = test_datagen.flow_from_dataframe(
      labels_xl,
      directory = test_80,
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=False,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
  )
  test_generator_50_percent = test_datagen.flow_from_dataframe(
      labels_xl,
      directory = test_50,
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=False,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
  )
  test_generator_30_percent = test_datagen.flow_from_dataframe(
      labels_xl,
      directory = test_30,
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=False,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
  )
  test_generator_15_percent = test_datagen.flow_from_dataframe(
      labels_xl,
      directory = test_15,
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=False,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
  )
  test_generator_15_secs = test_datagen.flow_from_dataframe(
      labels_xl,
      directory = test_15s,
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=False,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
  )
  test_generator_10_secs = test_datagen.flow_from_dataframe(
      labels_xl,
      directory = test_10s,
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=False,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
  )
  test_generator_5_secs = test_datagen.flow_from_dataframe(
      labels_xl,
      directory = test_5s,
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=False,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
  )
  test_generator_2_secs = test_datagen.flow_from_dataframe(
      labels_xl,
      directory = test_2s,
      x_col = 'code',
      y_col = 'Levels',
      target_size = (224,224),
      color_mode='rgb',
      shuffle=False,
      seed= 1,
      class_mode = 'categorical',
      batch_size = 16
  )

  return test_generator_full_images, test_generator_80_percent, test_generator_50_percent, test_generator_30_percent, test_generator_15_percent, test_generator_15_secs, test_generator_10_secs, test_generator_5_secs, test_generator_2_secs

# %%
# Load all images
test_full = pathtoImages + 'Test/'
test_80 = pathtoImages + test_percentage + 'Test_80/'
test_50 = pathtoImages + test_percentage + 'Test_50/'
test_30 = pathtoImages + test_percentage + 'Test_30/'
test_15 = pathtoImages + test_percentage + 'Test_15/'
test_15s = pathtoImages + test_timing + 'Test_15s/'
test_10s = pathtoImages + test_timing + 'Test_10s/'
test_5s = pathtoImages + test_timing + 'Test_5s/'
test_2s = pathtoImages + test_timing + 'Test_2s/'
test_generator_full_images, test_generator_80_percent, test_generator_50_percent,  test_generator_30_percent, test_generator_15_percent, test_generator_15_secs, test_generator_10_secs, test_generator_5_secs, test_generator_2_secs = load_test_images(test_full, test_80, test_50, test_30, test_15, test_15s, test_10s, test_5s, test_2s)
# Out:
# Found 250 validated image filenames belonging to 3 classes.
# Found 250 validated image filenames belonging to 3 classes.
# Found 250 validated image filenames belonging to 3 classes.
# Found 250 validated image filenames belonging to 3 classes.
# Found 250 validated image filenames belonging to 3 classes.
# Found 250 validated image filenames belonging to 3 classes.
# Found 250 validated image filenames belonging to 3 classes.
# Found 250 validated image filenames belonging to 3 classes.
# Found 250 validated image filenames belonging to 3 classes.

# %% [markdown]
# #6. Eval

# %%
evaluation_full = model.evaluate(test_generator_full_images)
evaluation_80 = model.evaluate(test_generator_80_percent)
evaluation_50 = model.evaluate(test_generator_50_percent)
evaluation_30 = model.evaluate(test_generator_30_percent)
evaluation_15 = model.evaluate(test_generator_15_percent)
# Out:
# 16/16 [==============================] - 138s 9s/step - loss: 1.5671 - accuracy: 0.6480 - recall: 0.1216 - auc: 0.7801 - PR: 0.6228 - f1macro: 0.5694 - f1weighted: 0.6165
# 16/16 [==============================] - 127s 8s/step - loss: 1.5715 - accuracy: 0.6480 - recall: 0.1102 - auc: 0.7569 - PR: 0.5996 - f1macro: 0.5576 - f1weighted: 0.6103
# 16/16 [==============================] - 126s 8s/step - loss: 1.5784 - accuracy: 0.5640 - recall: 0.0672 - auc: 0.7142 - PR: 0.5441 - f1macro: 0.5166 - f1weighted: 0.5583
# 16/16 [==============================] - 124s 8s/step - loss: 1.5975 - accuracy: 0.4360 - recall: 0.0229 - auc: 0.6469 - PR: 0.4534 - f1macro: 0.4311 - f1weighted: 0.4586
# 16/16 [==============================] - 127s 8s/step - loss: 1.6108 - accuracy: 0.3280 - recall: 0.0078 - auc: 0.5406 - PR: 0.3858 - f1macro: 0.3284 - f1weighted: 0.3367

# %%
evaluation_15s = model.evaluate(test_generator_15_secs)
evaluation_10s = model.evaluate(test_generator_10_secs)
evaluation_5s = model.evaluate(test_generator_5_secs)
evaluation_2s = model.evaluate(test_generator_2_secs)
# Out:
# 16/16 [==============================] - 126s 8s/step - loss: 1.5662 - accuracy: 0.6400 - recall: 0.1161 - auc: 0.7744 - PR: 0.6248 - f1macro: 0.5779 - f1weighted: 0.6175
# 16/16 [==============================] - 119s 8s/step - loss: 1.5716 - accuracy: 0.6040 - recall: 0.1057 - auc: 0.7438 - PR: 0.5913 - f1macro: 0.5535 - f1weighted: 0.5906
# 16/16 [==============================] - 123s 8s/step - loss: 1.5782 - accuracy: 0.5440 - recall: 0.0771 - auc: 0.7171 - PR: 0.5502 - f1macro: 0.5216 - f1weighted: 0.5492
# 16/16 [==============================] - 121s 8s/step - loss: 1.6122 - accuracy: 0.3200 - recall: 0.0039 - auc: 0.5488 - PR: 0.3828 - f1macro: 0.3206 - f1weighted: 0.3348

# %%
eval_percentage = {'dataset':  ['full', '80', '50', '30', '15'],
        'loss': [evaluation_full[0], evaluation_80[0], evaluation_50[0], evaluation_30[0], evaluation_15[0]],
        'accuracy': [evaluation_full[1], evaluation_80[1], evaluation_50[1], evaluation_30[1], evaluation_15[1]],
        'recall': [evaluation_full[2], evaluation_80[2], evaluation_50[2], evaluation_30[2], evaluation_15[2]],
        'auc': [evaluation_full[3], evaluation_80[3], evaluation_50[3], evaluation_30[3], evaluation_15[3]],
        'precision': [evaluation_full[4], evaluation_80[4], evaluation_50[4], evaluation_30[4], evaluation_15[4]],
        'f1_macro': [evaluation_full[5], evaluation_80[5], evaluation_50[5], evaluation_30[5], evaluation_15[5]],
        'f1_weighted': [evaluation_full[6], evaluation_80[6], evaluation_50[6], evaluation_30[6], evaluation_15[6]],
        }

eval_results_percentage = pd.DataFrame(eval_percentage)

# %%
percentage_csv_results = eval_results_percentage.to_csv(pathtoResults + 'eval_results_percentage.csv', index= True)

# %%
eval_results_percentage.plot(x= 'dataset', title = ['Loss', 'Accuracy', 'Recall', 'AUC', 'Precision', 'F1 macro', 'F1 weighted'], grid=True, subplots=True, layout=(4, 3), figsize = (30,30))
plt.savefig(pathtoResults + 'eval_percentage_results.png')

# %%
eval_timing = {'dataset':  ['full', '15s', '10s', '5s', '2s'],
        'loss': [evaluation_full[0], evaluation_15s[0], evaluation_10s[0], evaluation_5s[0], evaluation_2s[0]],
        'accuracy': [evaluation_full[1], evaluation_15s[1], evaluation_10s[1], evaluation_5s[1], evaluation_2s[1]],
        'recall': [evaluation_full[2], evaluation_15s[2], evaluation_10s[2], evaluation_5s[2], evaluation_2s[2]],
        'auc': [evaluation_full[3], evaluation_15s[3], evaluation_10s[3], evaluation_5s[3], evaluation_2s[3]],
        'precision': [evaluation_full[4], evaluation_15s[4], evaluation_10s[4], evaluation_5s[4], evaluation_2s[4]],
        'f1_macro': [evaluation_full[5], evaluation_15s[5], evaluation_10s[5], evaluation_5s[5], evaluation_2s[5]],
        'f1_weighted': [evaluation_full[6], evaluation_15s[6], evaluation_10s[6], evaluation_5s[6], evaluation_2s[6]],
        }

eval_results_timing = pd.DataFrame(eval_timing)

# %%
timing_csv_results = eval_results_timing.to_csv(pathtoResults + 'eval_results_timing.csv', index= True)

# %%
eval_results_timing.plot(x= 'dataset', title = ['Loss', 'Accuracy', 'Recall', 'AUC', 'Precision', 'F1 Macro', 'F1 Weighted'], grid=True, subplots=True, layout=(4, 3), figsize = (30, 30))
plt.savefig(pathtoResults + 'eval_timing_results.png')

# %% [markdown]
# #7. Save results as unique plot

# %%
hist_df_2
# Out:
#         loss  accuracy    recall  ...    val_PR  val_f1macro  val_f1weighted
# 0   1.568403  0.632110  0.127921  ...  0.585361     0.542144        0.603784
# 1   1.565825  0.644118  0.133567  ...  0.578031     0.555902        0.612962
# 2   1.568021  0.624118  0.118185  ...  0.581838     0.546761        0.608757
# 3   1.565127  0.633529  0.117601  ...  0.581713     0.537982        0.599324
# 4   1.560930  0.645294  0.118380  ...  0.583866     0.557656        0.612456
# 5   1.560864  0.649412  0.118380  ...  0.591870     0.552676        0.614365
# 6   1.559765  0.644118  0.123637  ...  0.590884     0.529597        0.592372
# 7   1.556171  0.648823  0.131036  ...  0.592478     0.543265        0.601687
# 8   1.557900  0.662353  0.125389  ...  0.599870     0.546779        0.608291
# 9   1.555536  0.660588  0.131425  ...  0.600319     0.544445        0.608420
# 10  1.556140  0.660000  0.125389  ...  0.599217     0.543054        0.607740
# 11  1.553507  0.666471  0.135514  ...  0.600937     0.542348        0.606784
# 12  1.553120  0.674706  0.126168  ...  0.600793     0.549056        0.614671
#
# [13 rows x 14 columns]

# %%
data1 = {'dataset':  ['val','full', '15s', '10s', '5s', '2s'],
        'loss': [hist_df_2.iloc[9,7],evaluation_full[0], evaluation_15s[0], evaluation_10s[0], evaluation_5s[0], evaluation_2s[0]],
        'accuracy': [hist_df_2.iloc[9,8],evaluation_full[1], evaluation_15s[1], evaluation_10s[1], evaluation_5s[1], evaluation_2s[1]],
        'auc': [hist_df_2.iloc[9,10],evaluation_full[3], evaluation_15s[3], evaluation_10s[3], evaluation_5s[3], evaluation_2s[3]],
        'precision': [hist_df_2.iloc[9,11],evaluation_full[4], evaluation_15s[4], evaluation_10s[4], evaluation_5s[4], evaluation_2s[4]],
        'f1macro': [hist_df_2.iloc[9,12],evaluation_full[5], evaluation_15s[5], evaluation_10s[5], evaluation_5s[5], evaluation_2s[5]],
        'f1weighted': [hist_df_2.iloc[9,13],evaluation_full[6], evaluation_15s[6], evaluation_10s[6], evaluation_5s[6], evaluation_2s[6]],
        }
data1 = pd.DataFrame(data1)
data1.to_csv(pathtoResults + 'results_Strategic_sophistication_timings.csv', index= True)

data2 = {'dataset':  ['val', 'full', '80', '50', '30', '15'],
        'loss': [hist_df_2.iloc[9,7],evaluation_full[0], evaluation_80[0], evaluation_50[0], evaluation_30[0], evaluation_15[0]],
        'accuracy': [hist_df_2.iloc[9,8],evaluation_full[1], evaluation_80[1], evaluation_50[1], evaluation_30[1], evaluation_15[1]],
        'auc': [hist_df_2.iloc[9,10],evaluation_full[3], evaluation_80[3], evaluation_50[3], evaluation_30[3], evaluation_15[3]],
        'precision': [hist_df_2.iloc[9,11],evaluation_full[4], evaluation_80[4], evaluation_50[4], evaluation_30[4], evaluation_15[4]],
        'f1macro': [hist_df_2.iloc[9,12],evaluation_full[5], evaluation_80[5], evaluation_50[5], evaluation_30[5], evaluation_15[5]],
        'f1weighted': [hist_df_2.iloc[9,13],evaluation_full[6], evaluation_80[6], evaluation_50[6], evaluation_30[6], evaluation_15[6]],
        }

data2 = pd.DataFrame(data2)
data2.to_csv(pathtoResults + 'results_Strategic_sophistication_percentages.csv', index= True)

# %%
def plot_all_results(data1, data2, name_file):
  metrics = ['loss_timings', 'loss_percentage', 'accuracy_timings', 'accuracy_percentages','auc_timings', 'auc_percentages', 'precision_timings', 'precision_percentages', 'f1macro_timings', 'f1macro_percentages', 'f1weighted_timings', 'f1weighted_percentages']
  fig, ax = plt.subplots(3,4, figsize=(30,20))
  fig.suptitle('VGG19 Model in Strategic Sophistication task Metric Plots',fontsize=40)
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    mtc = metric.split("_", 1)[0]
    plt.subplot(4,4,n+1)
    if n ==0:
      plt.plot(data1.iloc[:,0], data1[mtc], linewidth=3)
    elif n % 2 == 0:
      plt.plot(data1.iloc[:,0], data1[mtc], linewidth=3)
    else:
      plt.plot(data2.iloc[:,0], data2[mtc], linewidth=3)
    plt.xlabel('Dataset', fontsize=10)
    plt.title(str(name))
    plt.savefig(pathtoResults + name_file)

# %%
plot_all_results(data1, data2, "results_VGG_strategic_sophistication.png")
