# %% [markdown]
# #1. Setup

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
from shutil import copyfile

import pandas as pd

# %% [markdown]
# #2. Create folders with training and validation images organized by strategic behavior

# %%
rootdir1 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Train_SVM_EQ'
output_path1 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Train_SVM_EQ/'
csv1 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/CSV_Files/Training_Reshuffle.csv'

rootdir2 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Val_SVM_EQ'
output_path2 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Val_SVM_EQ/'
csv2 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/CSV_Files/Validation_Reshuffle.csv'

# %%
no_ds = pd.read_csv(csv1)
no_ds.columns
# Out:
# Index(['Class', 'File_Name'], dtype='object')

# %%
for name in no_ds['File_Name'][no_ds['Class']==1]:
  os.rename(rootdir1+'/'+name, rootdir1+'/EQ/'+name)

# %%
for name in no_ds['File_Name'][no_ds['Class']==0]:
  os.rename(rootdir1+'/'+name, rootdir1+'/Non_EQ/'+name)

# %%
# %%bash
# cd /content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Train_SVM_EQ/EQ
# ls -d | wc *.jpg
# Out:
#      1303      4535    315459 fase1_002e1_10.jpg
#      4940      7762    269644 fase1_002e1_13.jpg
#      1233      3722    251418 fase1_002e1_15.jpg
#      1341      4687    312879 fase1_002e1_1.jpg
#      1407      4172    266479 fase1_002e1_2.jpg
#      1485      4335    270012 fase1_002e1_4.jpg
#      5003      7607    256582 fase1_002e1_5.jpg
#      1385      3985    257082 fase1_002e1_6.jpg
#      1304      4319    272747 fase1_002e1_7.jpg
#      1282      3635    236615 fase1_002e1_9.jpg
#      1676      6016    389833 fase1_003e1_11.jpg
#      1427      4528    300559 fase1_003e1_12.jpg
#      1374      4914    329395 fase1_003e1_13.jpg
#      1900      5454    339440 fase1_003e1_15.jpg
#      1614      5283    342034 fase1_003e1_1.jpg
#      1482      4941    324806 fase1_003e1_2.jpg
#      5155      8887    351590 fase1_003e1_4.jpg
#      5407      9175    351625 fase1_003e1_5.jpg
#      1552      5102    310180 fase1_003e1_7.jpg
# ...

# %%
del no_ds

# %%
no_ds = pd.read_csv(csv2)
no_ds.columns
# Out:
# Index(['Class', 'File_Name'], dtype='object')

# %%
for name in no_ds['File_Name'][no_ds['Class']==1]:
  os.rename(rootdir2+'/'+name, rootdir2+'/EQ/'+name)

# %%
for name in no_ds['File_Name'][no_ds['Class']==0]:
  os.rename(rootdir2+'/'+name, rootdir2+'/Non_EQ/'+name)

# %%
# %%bash
# cd /content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Val_SVM_EQ/EQ
# ls -d | wc *.jpg
# Out:
#     1319     3972   249609 fase1_016e1_10.jpg
#     1649     4482   269970 fase1_016e1_11.jpg
#     1294     3684   238462 fase1_016e1_13.jpg
#     1496     4194   252130 fase1_016e1_15.jpg
#     1097     3241   219276 fase1_016e1_3.jpg
#     1160     3724   247690 fase1_016e1_4.jpg
#     1564     3842   229390 fase1_016e1_5.jpg
#     1403     3855   237346 fase1_016e1_6.jpg
#     1265     4045   247064 fase1_016e1_8.jpg
#     1228     3740   251957 fase1_01e1_3.jpg
#     1546     4899   321615 fase1_020e1_10.jpg
#     1433     5219   342358 fase1_020e1_12.jpg
#     1289     4430   292940 fase1_020e1_13.jpg
#     1580     5248   338882 fase1_020e1_14.jpg
#     5002     8174   302105 fase1_020e1_15.jpg
#     1469     5186   341266 fase1_020e1_6.jpg
#     1665     5246   335074 fase1_020e1_9.jpg
#     1426     4132   265907 fase1_022e1_10.jpg
#     1431     3914   237479 fase1_022e1_12.jpg
#     1466     3938   242639 fase1_022e1_14.jpg
#     1341     3707   230798 fase1_022e1_15.jpg
# ...
