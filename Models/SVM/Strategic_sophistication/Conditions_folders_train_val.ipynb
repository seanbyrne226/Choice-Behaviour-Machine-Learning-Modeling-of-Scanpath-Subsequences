# %% [markdown]
# # 1. Setup

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# #2. Create folders with training and validation images organized by strategic behavior

# %%
import os
from shutil import copyfile

import pandas as pd

rootdir1 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Train_SVM_Strategic_sophistication'
output_path1 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Train_SVM_Strategic_sophistication/'
csv1 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/CSV_Files/train_L1L2.csv'

rootdir2 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Val_SVM_Strategic_sophistication'
output_path2 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Val_SVM_Strategic_sophistication/'
csv2 = '/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/CSV_Files/val_L1L2.csv'

# %%
no_ds = pd.read_csv(csv1)
no_ds.columns
# Out:
# Index(['code', 'Levels'], dtype='object')

# %%
for name in no_ds['code'][no_ds['Levels']==0]:
  os.rename(rootdir1+'/'+name, rootdir1+'/cooperative/'+name)

# %%
for name in no_ds['code'][no_ds['Levels']==1]:
  os.rename(rootdir1+'/'+name, rootdir1+'/Level_1/'+name)

# %%
for name in no_ds['code'][no_ds['Levels']==2]:
  os.rename(rootdir1+'/'+name, rootdir1+'/equilibrium/'+name)

# %%
# %%bash
# cd /content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Train_SVM_Strategic_sophistication/cooperative
# ls -d | wc *.jpg
# Out:
#     1219     3811   246065 fase1_004e1_3.jpg
#     4921     7520   256995 fase1_004e1_4.jpg
#     1343     4790   330599 fase1_005e1_10.jpg
#     1325     4416   288020 fase1_005e1_11.jpg
#     1672     5079   316899 fase1_005e1_13.jpg
#     1404     3981   253376 fase1_005e1_2.jpg
#     1366     3963   260531 fase1_005e1_3.jpg
#     1321     4158   276501 fase1_005e1_4.jpg
#     1859     5525   337534 fase1_005e1_5.jpg
#     1441     4448   262207 fase1_005e1_6.jpg
#     1550     4406   276091 fase1_005e1_8.jpg
#     1365     4217   272737 fase1_007e1_15.jpg
#     1221     3286   214515 fase1_007e1_2.jpg
#     1100     3452   238426 fase1_007e1_4.jpg
#     1367     3990   243264 fase1_007e1_9.jpg
#     1780     5047   310839 fase1_008e1_12.jpg
#     1140     4435   288336 fase1_008e1_13.jpg
#     1438     5272   350026 fase1_008e1_1.jpg
#     1272     4531   291536 fase1_008e1_4.jpg
#     1389     4729   290659 fase1_008e1_7.jpg
#     1491     5377   367279 fase1_008e1_8.jpg
# ...

# %%
del no_ds

# %%
no_ds = pd.read_csv(csv2)
no_ds.columns
# Out:
# Index(['code', 'Levels'], dtype='object')

# %%
for name in no_ds['code'][no_ds['Levels']==0]:
  os.rename(rootdir2+'/'+name, rootdir2+'/cooperative/'+name)

# %%
for name in no_ds['code'][no_ds['Levels']==1]:
  os.rename(rootdir2+'/'+name, rootdir2+'/Level_1/'+name)

# %%
for name in no_ds['code'][no_ds['Levels']==2]:
  os.rename(rootdir2+'/'+name, rootdir2+'/equilibrium/'+name)

# %%
# %%bash
# cd /content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Images/Val_SVM_Strategic_sophistication/cooperative
# ls -d | wc *.jpg
# Out:
#     4968     7548   246015 fase1_01e1_11.jpg
#     1472     5234   357040 fase1_020e1_1.jpg
#     1359     4177   266681 fase1_020e1_2.jpg
#     1547     5846   387853 fase1_020e1_5.jpg
#     1552     4648   296769 fase1_02e2_3.jpg
#     1165     3520   233579 fase1_050e1_13.jpg
#     4944     7183   226336 fase1_050e1_14.jpg
#     1178     3622   235820 fase1_050e1_3.jpg
#     1128     3746   239109 fase1_050e1_7.jpg
#     1477     3705   221634 fase1_050e1_8.jpg
#     1523     5327   357934 fase1_054e1_3.jpg
#     1422     5089   349596 fase1_054e1_4.jpg
#     1612     5117   331724 fase1_054e1_7.jpg
#     1323     4320   292640 fase1_066e1_13.jpg
#     5071     7530   242776 fase1_066e1_1.jpg
#     1214     3331   213291 fase1_091e1_12.jpg
#     1360     3579   230340 fase1_091e1_14.jpg
#     5005     6981   197282 fase1_091e1_4.jpg
#     1395     3487   216608 fase1_091e1_5.jpg
#     1276     3500   218599 fase1_091e1_6.jpg
#     1137     2912   195357 fase1_097e1_2.jpg
# ...
