# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Define paths:
pathtoResults = r'/content/drive/Shareddrives/Eye_Tracking_NN_SD/Image_processing/Publishable_material/Models_performance/Logit/'

# %% [markdown]
# #2. Load saved performance results

# %%
# Read results:
rt = pd.read_csv (pathtoResults + 'outcome_Multinom_timing.csv')
rp = pd.read_csv (pathtoResults + 'outcome_Multinom_percentage.csv')

# %% [markdown]
# # 3. Plot results by timings and percentages

# %%
def plot_metrics(data1, data2, name_file):
  metrics = ['Accuracy_timings', 'Accuracy_percentages', 'AUC_timings', 'AUC_percentages', 'Precision_timings', 'Precision_percentages', 'f1_timings', 'f1_percentages']
  fig, ax = plt.subplots(2,4, figsize=(30,20))
  fig.suptitle('Multinomial Logit Model Metric Plots',fontsize=40)
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    mtc = metric.split("_", 1)[0]
    plt.subplot(2,4,n+1)
    if n ==0:
      plt.plot(data1.iloc[:,1], data1[mtc], linewidth=3)
    elif n % 2 == 0:
      plt.plot(data1.iloc[:,1], data1[mtc], linewidth=3)
    else:
      plt.plot(data2.iloc[:,1], data2[mtc], linewidth=3)
    plt.xlabel('Dataset', fontsize=10)
    plt.title(str(name))
    plt.savefig(pathtoResults + name_file)

# %%
plot_metrics(rt, rp, "results_Multinom_strategic_sophistication.png")

# %%
'''
mt = pd.read_csv (pathtoResults + 'results_mapk_timing.csv')
mp = pd.read_csv (pathtoResults + 'results_mapk_percentage.csv')
def plot_mapk(data1, data2, name_file):
  metrics = ['mapk_timings', 'mapk_percentages']
  fig, ax = plt.subplots(1,2, figsize=(30,20))
  fig.suptitle('Mean Average Precision at k for Multinomial Model',fontsize=40)
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    mtc = metric.split("_", 1)[0]
    plt.subplot(1,2,n+1)
    if n ==0:
      plt.plot(data1.iloc[:,1], data1[mtc], linewidth=3)
    elif n % 2 == 0:
      plt.plot(data1.iloc[:,1], data1[mtc], linewidth=3)
    else:
      plt.plot(data2.iloc[:,1], data2[mtc], linewidth=3)
    plt.xlabel('Dataset', fontsize=10)
    plt.title(str(name))
    plt.savefig(pathtoResults + name_file)
    
plot_mapk(mt, mp, "mapk_Multinomial.png")'''
# Out:
# '\nmt = pd.read_csv (pathtoResults + \'results_mapk_timing.csv\')\nmp = pd.read_csv (pathtoResults + \'results_mapk_percentage.csv\')\ndef plot_mapk(data1, data2, name_file):\n  metrics = [\'mapk_timings\', \'mapk_percentages\']\n  fig, ax = plt.subplots(1,2, figsize=(30,20))\n  fig.suptitle(\'Mean Average Precision at k for Multinomial Model\',fontsize=40)\n  for n, metric in enumerate(metrics):\n    name = metric.replace("_"," ").capitalize()\n    mtc = metric.split("_", 1)[0]\n    plt.subplot(1,2,n+1)\n    if n ==0:\n      plt.plot(data1.iloc[:,1], data1[mtc], linewidth=3)\n    elif n % 2 == 0:\n      plt.plot(data1.iloc[:,1], data1[mtc], linewidth=3)\n    else:\n      plt.plot(data2.iloc[:,1], data2[mtc], linewidth=3)\n    plt.xlabel(\'Dataset\', fontsize=10)\n    plt.title(str(name))\n    plt.savefig(pathtoResults + name_file)\n    \nplot_mapk(mt, mp, "mapk_Multinomial.png")'
